# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
file_path = r'emis_meic_cb6r3_ae7_aq_20240905_d02_daily.nc'
ds = xr.open_dataset(file_path)
ds
# Out:
# <xarray.Dataset> Size: 10GB
# Dimensions:          (TSTEP: 25, VAR: 64, DATE-TIME: 2, LAY: 34, ROW: 205,
#                       COL: 235)
# Dimensions without coordinates: TSTEP, VAR, DATE-TIME, LAY, ROW, COL
# Data variables: (12/65)
#     TFLAG            (TSTEP, VAR, DATE-TIME) int32 13kB ...
#     CO               (TSTEP, LAY, ROW, COL) float32 164MB ...
#     NO               (TSTEP, LAY, ROW, COL) float32 164MB ...
#     NO2              (TSTEP, LAY, ROW, COL) float32 164MB ...
#     SO2              (TSTEP, LAY, ROW, COL) float32 164MB ...
#     NH3              (TSTEP, LAY, ROW, COL) float32 164MB ...
#     ...               ...
#     PMCOARSE_SOIL    (TSTEP, LAY, ROW, COL) float32 164MB ...
#     PMCOARSE_SO4     (TSTEP, LAY, ROW, COL) float32 164MB ...
#     PMCOARSE_NO3     (TSTEP, LAY, ROW, COL) float32 164MB ...
#     PMCOARSE_CL      (TSTEP, LAY, ROW, COL) float32 164MB ...
#     PMCOARSE_H2O     (TSTEP, LAY, ROW, COL) float32 164MB ...
# ...

# %%
ds['CO'].isel(TSTEP=23,LAY=0).plot()
plt.show()

# %%
ds.close()
