# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
file_path=r'B3GRD_d02.nc'
ds=xr.open_dataset(file_path)
ds
# Out:
# <xarray.Dataset> Size: 15MB
# Dimensions:           (TSTEP: 1, VAR: 77, DATE-TIME: 2, LAY: 1, ROW: 205,
#                        COL: 235)
# Dimensions without coordinates: TSTEP, VAR, DATE-TIME, LAY, ROW, COL
# Data variables: (12/78)
#     TFLAG             (TSTEP, VAR, DATE-TIME) int32 616B ...
#     AVG_ISOPS         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_MBOS          (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_METHS         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_APINS         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_BPINS         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     ...                ...
#     LAI_ISOPW         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     LAI_MBOW          (TSTEP, LAY, ROW, COL) float32 193kB ...
#     LAI_METHW         (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_NOAG_GROW     (TSTEP, LAY, ROW, COL) float32 193kB ...
#     AVG_NOAG_NONGROW  (TSTEP, LAY, ROW, COL) float32 193kB ...
# ...

# %%
ds['AVG_ISOPS'].isel(TSTEP=0).plot()
plt.show()

# %%
ds.close()
