# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
file_path=r'emis_meic_cb6r3_ae7_aq_20240905_d03_daily.nc'
ds=xr.open_dataset(file_path)
ds
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:          (TSTEP: 25, LAY: 34, ROW: 127, COL: 151, VAR: 64,
#                       DATE-TIME: 2)
# Dimensions without coordinates: TSTEP, LAY, ROW, COL, VAR, DATE-TIME
# Data variables: (12/65)
#     CO               (TSTEP, LAY, ROW, COL) float32 65MB ...
#     NO               (TSTEP, LAY, ROW, COL) float32 65MB ...
#     NO2              (TSTEP, LAY, ROW, COL) float32 65MB ...
#     SO2              (TSTEP, LAY, ROW, COL) float32 65MB ...
#     NH3              (TSTEP, LAY, ROW, COL) float32 65MB ...
#     HCL              (TSTEP, LAY, ROW, COL) float32 65MB ...
#     ...               ...
#     PMCOARSE_SO4     (TSTEP, LAY, ROW, COL) float32 65MB ...
#     PMCOARSE_NO3     (TSTEP, LAY, ROW, COL) float32 65MB ...
#     PMCOARSE_CL      (TSTEP, LAY, ROW, COL) float32 65MB ...
#     PMCOARSE_H2O     (TSTEP, LAY, ROW, COL) float32 65MB ...
#     PMCOARSE_SEACAT  (TSTEP, LAY, ROW, COL) float32 65MB ...
# ...

# %%
ds['PFE'].isel(TSTEP=7,LAY=0).plot()
plt.show()

# %%
ds.close()
